# %% [markdown]
# <h2> <font color='greenblue'>1. Para Análisis de Datos (SQL, Python, Tableau)</h2>
#
# <h3>  <font color='greenblue'; font-weight:bold;> Rol:   Actúa como un analista de datos experto y mentor.</h3>
#
# <font color='greenblue'>Contexto y Tarea:
#
# Tengo una base de datos PostgreSQL con una tabla [ventas] que incluye [fecha_venta], [id_producto], [cantidad] y [precio_unitario]. Necesito calcular [el total de ventas por mes para el último año].
#
# Paso 1: Proporciona la consulta [SQL] necesaria.
#
# Paso 2: Luego, dame el código [Python] usando [Pandas] para cargar los resultados de esta consulta y calcular el [promedio de cantidad vendida por producto].
#
# Paso 3: Finalmente, describe los pasos clave para visualizar el [total de ventas mensuales] en Tableau, indicando qué tipo de gráfico sería el más adecuado."

# %% [markdown]
# <font color='greenblue'>Solicitud Específica:
#
# "Eres un experto en optimización de consultas [SQL]. Explícame en términos muy sencillos y con un ejemplo práctico, cómo el uso de [índices] puede mejorar el rendimiento de una consulta [SELECT] compleja en una tabla grande. Pásamelo en un esquema con viñetas."

# %% [markdown]
# <font color='greenblue'>Corrección/Reescritura:
#
# Tengo este script de [Python] que limpia datos, pero creo que no es eficiente: [inserta tu código Python aquí]. Reescribe este código para que sea más claro y más rápido, explicando las mejoras línea por línea.

# %% [markdown]
# <font color='greenblue'>Generación de Datos de ejemplo
#
# Necesito un conjunto de datos de ejemplo en formato [CSV] para probar un tablero en Tableau. Genera [20] filas de datos para una tabla de [clientes] con las columnas [ID_Cliente], [Nombre], [País], [Ciudad], [Gasto_Promedio] y [Fecha_Registro]. Asegúrate de que [Gasto_Promedio] contenga valores numéricos y [Fecha_Registro] fechas variadas del último año.

# %% [markdown]
# <h2> <font color='greenblue'>2. Para compra y alternativas cotidianas</h2>
#
# <h3>  <font color='greenblue'; font-weight:bold;> Rol: Eres un asistente de compras inteligente que valora la relación calidad-precio y la sostenibilidad.</h3>
#
# <font color='greenblue'>Contexto y Tarea:

# %% [markdown]
# Quiero comprar [una bicicleta de montaña para principiantes], mi presupuesto máximo es de [$800.000 CLP]. La usaré principalmente en [senderos ligeros y para ir al trabajo].
#
# Paso 1: Dame 3 alternativas de [bicicletas] que cumplan con estos requisitos, mencionando marca, modelo y rango de precio estimado en CLP.
#
# Paso 2: Para cada alternativa, dame los pros y contras en formato tabla, considerando [durabilidad, facilidad de mantenimiento y comodidad].
#
# Paso 3: Dame tu recomendación final y una breve justificación."

# %% [markdown]
# <font color='greenblue'>Alternativas de regalo:
#
# Necesito ideas de regalos originales para [mi mamá] que cumple [60] años. Le gusta [la jardinería, la lectura y el café]. Mi presupuesto es de [$50.000 - $100.000 CLP]. Dame 5 ideas en formato de lista, con una breve descripción y una estimación de precio."

# %% [markdown]
# <h2> <font color='greenblue'>3. Para proyectos y síntesis de información</h2>
#
# <h3>  <font color='greenblue'; font-weight:bold;> Rol: Actúa como un consultor de proyectos y un experto en comunicación efectiva.</h3>
#
# <font color='greenblue'>Enunciado de Proyecto:
#
# Ayúdame a crear un enunciado de proyecto claro y conciso para un proyecto personal. El objetivo es [construir una aplicación web simple que permita a los usuarios registrar sus entrenamientos diarios de natación (distancia, tiempo, estilo)]. Debe incluir un objetivo SMART y los principales hitos. Pásamelo en un esquema con secciones bien definidas.

# %% [markdown]
# <font color='greenblue'>Síntesis de información (artículo/documento):
#
# Aquí tienes un texto: [inserta aquí un artículo, un informe o una sección de un documento de hasta 1000 palabras].
#
# Paso 1: Haz una síntesis ejecutiva de este texto en un máximo de 150 palabras.
#
# Paso 2: Luego, extrae los 5 puntos clave principales en una lista numerada.
#
# Paso 3: Si es un tema complejo, dame un glosario con 3-5 términos técnicos importantes y su explicación sencilla.

# %% [markdown]
# <font color='greenblue'>Cuadro Resumen:
#
# Tengo información dispersa sobre [los diferentes tipos de aprendizaje automático (supervisado, no supervisado, por refuerzo)]. Crea un cuadro resumen que incluya para cada tipo: definición, ejemplos de algoritmos y casos de uso comunes. Usa un formato de tabla claro.

# %% [markdown]
# <font color='greenblue'>Esquema para Comprender un Tema:
#
# Quiero entender mejor el concepto de ['machine learning'] para alguien que recién empieza. Dame un esquema paso a paso que explique: qué es, por qué es importante, cómo funciona de forma básica y sus aplicaciones comunes. Usa un lenguaje muy sencillo y sin jerga técnica compleja.
